# %% [markdown]
# # Importing Reqirments.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import pint
import os
import pandas as pd

# %% [markdown]
# # Importing Data

# %%
# Configurations: (P/S)_xC_YR == p: parallel, S: Series, C: capasitance, R: Resistance 
file_path = "DATA/"
configurations = ["parallel/", "series/"]

DATA = {
    "Parallel":{
        "P_1c_220R": pd.read_csv(file_path+configurations[0]+"1c 220r" , sep="\t"),
        "P_22c_220R": pd.read_csv(file_path+configurations[0]+"2,2c 220r" , sep="\t"),
        "P_22c_470R": pd.read_csv(file_path+configurations[0]+"2,2c 470r" , sep="\t"),
        "P_22c_680R": pd.read_csv(file_path+configurations[0]+"2,2c 680r" , sep="\t"),
        "P_47c_220R": pd.read_csv(file_path+configurations[0]+"4,7c 220r" , sep="\t")

    },
    "Series": {
        "S_1c_220R ": pd.read_csv(file_path+configurations[1]+"1c 220r" , sep="\t"),
        "S_22c_220R": pd.read_csv(file_path+configurations[1]+"2,2c 220r" , sep="\t"),
        "S_22c_470R": pd.read_csv(file_path+configurations[1]+"2,2c 470r" , sep="\t"),
        "S_22c_680R": pd.read_csv(file_path+configurations[1]+"2,2c 680r" , sep="\t"),
        "S_47c_220R": pd.read_csv(file_path+configurations[1]+"4,7c 220r" , sep="\t")
    }
}

# %%
DATA["Parallel"]["P_1c_220R"]
# Out:
#    Frequency frq Current I Voltage U2 Impedance Z
# 0         frq/Hz      I/mA      U2/mV       Z/Ohm
# 1             20     47,56       4119       86,62
# 2             40     45,60       4338       95,13
# 3             60     42,89       4649      108,41
# 4             80     40,49       4923      121,57
# 5            100     38,00       5167      135,98
# 6            120     35,99       5363      149,04
# 7            140     34,36       5500      160,09
# 8            160     33,16       5642      170,14
# 9            180     32,18       5726      177,94
# 10           200     31,53       5806      184,14
# 11           220     31,10       5866      188,64
# 12           240     30,66       5918      193,01
# 13           260     30,23       5960      197,19
# 14           280     29,95       5990      199,97
# 15           300     29,68       5995      201,97
# 16           320     29,68       6025      202,98
# 17           340     29,57       6045      204,40
# ...

# %%
for configuration in DATA.keys():
    print(configuration)
    for combination_data in DATA[configuration].values():
        print(".")
# Out:
# Parallel
# .
# .
# .
# .
# .
# Series
# .
# .
# .
# .
# .
